# %% [markdown]
# <a href="https://colab.research.google.com/github/RakeshRegala/ML-Workshop/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Create a Pandas DataFrame from the following dictionary:
# data = {
#  'Name': ['Alice', 'Bob', 'Carol'],
#  'Age': [24, 27, 22],
#  'Salary': [50000, 55000, 48000]
# }
# • Add a new column called Bonus which is 10% of the salary.

# %%
import pandas as pd
data = { 'Name': ['Alice', 'Bob', 'Carol'], 'Age': [24, 27, 22], 'Salary': [50000, 55000, 48000] }
df=pd.DataFrame(data)
df['Bonus']=df['Salary']*0.1
df
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0

# %% [markdown]
# #2. Given the DataFrame created in the above question:
# • Display the first two rows.
# • Compute the mean salary.

# %%
print(df.head(2))
# Calculating the mean salary
mean_salary = df['Salary'].mean()
mean_salary
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 51000.0

# %% [markdown]
# #3. Using the same DataFrame:
# • Extract all rows where the Age is greater than 25.
# • Filter out rows where the Salary is less than 50000

# %%
age_greater_25 = df[df['Age'] > 25]
age_greater_25
salary_greater_50000 = df[df['Salary'] >= 50000]
salary_greater_50000
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0

# %% [markdown]
# #4. Create the following DataFrame:
# data = {
#  'A': [1, 2, None, 4],
#  'B': [None, 2, 3, None],
#  'C': [1, 2, 3, 4]
# }
# df = pd.DataFrame(data)
# • Fill missing values in column A with the mean of the column.
# • Drop rows where all values are None

# %%
data = { 'A': [1, 2, None, 4], 'B': [None, 2, 3, None], 'C': [1, 2, 3, 4] }
df = pd.DataFrame(data)
mean_A = df['A'].mean()
df['A'] = df['A'].fillna(mean_A)

# Drop rows where all values are None
df = df.dropna(how='all')
df
# Out:
#           A    B  C
# 0  1.000000  NaN  1
# 1  2.000000  2.0  2
# 2  2.333333  3.0  3
# 3  4.000000  NaN  4

# %% [markdown]
# #5. Create a DataFrame for employees:
# data = {
#  'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
#  'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
#  'Salary': [50000, 45000, 60000, 65000, 70000]
# }
# • Group the data by Department and compute the total and mean salary for each
# department.

# %%
data = { 'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'], 'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'], 'Salary': [50000, 45000, 60000, 65000, 70000] }
df = pd.DataFrame(data)
grouped = df.groupby('Department')
total_salary = grouped['Salary'].sum()
mean_salary = grouped['Salary'].mean()
print(total_salary)
print(mean_salary)
# Out:
# Department
# Finance     70000
# HR          95000
# IT         125000
# Name: Salary, dtype: int64
# Department
# Finance    70000.0
# HR         47500.0
# IT         62500.0
# Name: Salary, dtype: float64

# %% [markdown]
# #6. Given two DataFrames:
# df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
# df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
# • Perform an inner join on the ID column.

# %%
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
inner_join = pd.merge(df1, df2, on='ID', how='inner')
inner_join
# Out:
#    ID   Name  Age
# 0   2    Bob   25
# 1   3  Carol   30

# %% [markdown]
# #7. Given a small dataset, clean and display basic statistics using Pandas.

# %%
# Task 7
# Given a small dataset, clean and display basic statistics
data = {
    'Name': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Age': [25, None, 30, 35, None],
    'Salary': [50000, 45000, 60000, 65000, 70000]
}
small_df = pd.DataFrame(data)

# Fill missing values in Age with the mean age
mean_age = small_df['Age'].mean()
small_df['Age'] = small_df['Age'].fillna(mean_age)

# Display basic statistics
statistics = small_df.describe()

# Display results
print("Cleaned Dataset:")
print(small_df)
print("\nBasic Statistics of Small Dataset:")
print(statistics)
# Out:
# Cleaned Dataset:
#     Name   Age  Salary
# 0  Alice  25.0   50000
# 1    Bob  30.0   45000
# 2  Carol  30.0   60000
# 3  David  35.0   65000
# 4    Eve  30.0   70000
#
# Basic Statistics of Small Dataset:
#              Age        Salary
# count   5.000000      5.000000
# mean   30.000000  58000.000000
# std     3.535534  10368.220677
# min    25.000000  45000.000000
# 25%    30.000000  50000.000000
# 50%    30.000000  60000.000000
# 75%    30.000000  65000.000000
# max    35.000000  70000.000000

# %% [markdown]
# #8. small EDA task
# • Load the Titanic dataset (titanic.csv) into a Pandas DataFrame.
# • Perform the following tasks:
# o Display the number of missing values in each column.
# o Find the average age of passengers.
# o Create a bar plot to show the survival rate based on gender.

# %%
import matplotlib.pyplot as plt

titanic_df = pd.read_csv('/content/Titanic-Dataset.csv')

# Display the number of missing values in each column
missing_values = titanic_df.isnull().sum()

# Find the average age of passengers
average_age = titanic_df['Age'].mean()

# Create a bar plot to show the survival rate based on gender
survival_rate = titanic_df.groupby('Sex')['Survived'].mean()
survival_rate.plot(kind='bar', color=['blue', 'orange'])
plt.title('Survival Rate by Gender')
plt.ylabel('Survival Rate')
plt.xlabel('Gender')
plt.show()
average_age
# Out:
# 29.69911764705882

# %% [markdown]
# #9. Data Transformation
# • Load a dataset containing daily temperatures and dates. Perform the following:
# o Convert the date column into a DateTime object.
# o Create a new column that categorizes temperatures into High, Medium, or
# Low.

# %%
data = {
    'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04'],
    'Temperature': [30, 22, 15, 10]
}
temp_df = pd.DataFrame(data)

# Convert the date column into a DateTime object
temp_df['Date'] = pd.to_datetime(temp_df['Date'])

# Create a new column that categorizes temperatures into High, Medium, or Low
def categorize_temperature(temp):
    if temp > 25:
        return 'High'
    elif 15 <= temp <= 25:
        return 'Medium'
    else:
        return 'Low'

temp_df['Temperature_Category'] = temp_df['Temperature'].apply(categorize_temperature)
temp_df
# Out:
#         Date  Temperature Temperature_Category
# 0 2023-01-01           30                 High
# 1 2023-01-02           22               Medium
# 2 2023-01-03           15               Medium
# 3 2023-01-04           10                  Low
